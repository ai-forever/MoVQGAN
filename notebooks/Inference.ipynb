# %%
import torch
import requests
import numpy as np
from PIL import Image
from io import BytesIO
import torchvision.transforms as T
from torch.nn.functional import mse_loss, l1_loss
from movqgan import get_movqgan_model

# %%
model = get_movqgan_model('270M', pretrained=True, device='cuda')
# Out:
# /home/jovyan/.imgenv-maltseva-test6-0/lib/python3.7/site-packages/torch/distributed/_sharded_tensor/__init__.py:10: DeprecationWarning: torch.distributed._sharded_tensor will be deprecated, use torch.distributed._shard.sharded_tensor instead
#   DeprecationWarning
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# /home/jovyan/.imgenv-maltseva-test6-0/lib/python3.7/site-packages/huggingface_hub/file_download.py:654: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   FutureWarning,
# Downloading movqgan_270M.ckpt:   0%|          | 0.00/1.08G [00:00<?, ?B/s]

# %%
def show_images(batch, return_image=False):
    """ Display a batch of images inline. """
    scaled = ((batch + 1)*127.5).round().clamp(0,255).to(torch.uint8).cpu()
    reshaped = scaled.permute(2, 0, 3, 1).reshape([batch.shape[2], -1, 3])
    if return_image:
        return Image.fromarray(reshaped.numpy())
    display(Image.fromarray(reshaped.numpy()))

# %%
def prepare_image(img):
    """ Transform and normalize PIL Image to tensor. """
    transform = T.Compose([
            T.RandomResizedCrop(512, scale=(1., 1.), ratio=(1., 1.), interpolation=T.InterpolationMode.BICUBIC),
        ])
    pil_image = transform(img)
    arr = np.array(pil_image.convert("RGB"))
    arr = arr.astype(np.float32) / 127.5 - 1
    return torch.from_numpy(np.transpose(arr, [2, 0, 1]))

# %%
url = "https://look.com.ua/pic/201609/1024x768/look.com.ua-177244.jpg"
response = requests.get(url)
img = prepare_image(Image.open(BytesIO(response.content)))

# %%
# Input
show_images(img.unsqueeze(0))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9080DBBED0>

# %%
# %%time
with torch.no_grad():
    out = model(img.to('cuda').unsqueeze(0))[0]
# Out:
# CPU times: user 867 ms, sys: 565 ms, total: 1.43 s
# Wall time: 3.42 s

# %%
# Output
show_images(out)
mse = mse_loss(out, img.to('cuda').unsqueeze(0))
l1 = l1_loss(out, img.to('cuda').unsqueeze(0))
print('mse =', np.round(mse.item(),4), 'l1 =', np.round(l1.item(),4))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9080D9A550>
# mse = 0.0034 l1 = 0.0324

# %%
# absolute difference between input and output
show_images(torch.abs(out - img.to('cuda').unsqueeze(0)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F905E6E0D50>
